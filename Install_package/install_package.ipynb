# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.__version__
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
pip install konlpy
# Out:
# ...
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ----------------------- ---------------- 11.3/19.4 MB 57.0 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 52.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 48.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [lxml]
#    ---------------------------------------- 0/3 [lxml]
#    ------------- -------------------------- 1/3 [JPype1]
#    -------------------------- ------------- 2/3 [konlpy]
#    -------------------------- ------------- 2/3 [konlpy]
#    ---------------------------------------- 3/3 [konlpy]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import konlpy

# %%
konlpy.__version__
# Out:
# '0.6.0'
