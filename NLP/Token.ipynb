# %%
# 토큰화
# 말을 토큰화 하다보면 예상치 못한 문제가 발생함!!!
# 흐름에 맞게 끊어야 하는데 . , ' 등 다양한 변수가 존재함
# e.g. Ph.d 랑 New york Don't 이건 한 단위인데 끊으면 문제가 생김

# %%
# !pip install kss
# Out:
# ...
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 1.1/1.1 MB 27.6 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#      ----------------- --------------------- 12.1/26.4 MB 57.8 MB/s eta 0:00:01
#      ----------------------------------- --- 23.9/26.4 MB 58.0 MB/s eta 0:00:01
#      ---------------------------------------- 26.4/26.4 MB 53.9 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
print('단어 토큰화 : ',word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage "
"is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화 :  ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('단어 토큰화 : ',WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage "
"is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화 :  ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('단어 토큰화 : ',text_to_word_sequence("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage "
"is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화 :  ["don't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', 'mr', "jone's", 'orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']

# %%
import kss

# %%
text = '문제는 영어보다 한국어 자연어처리가 너무 어렵습니다. 이제 해보면 알걸요?'
print('한국어 문장 토큰화 : ',kss.split_sentences(text))
# Out:
# 한국어 문장 토큰화 :  ['문제는 영어보다 한국어 자연어처리가 너무 어렵습니다.', '이제 해보면 알걸요?']
