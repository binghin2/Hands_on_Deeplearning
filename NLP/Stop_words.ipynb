# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from konlpy.tag import Okt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from nltk.corpus import stopwords
#       2 from nltk.tokenize import word_tokenize
# ----> 3 from konlpy.tag import Okt
#
# ModuleNotFoundError: No module named 'konlpy'

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\.conda\envs\myenv\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\.conda\envs\myenv\lib\site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: packaging in c:\users\user\.conda\envs\myenv\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)

# %%
import nltk

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from konlpy.tag import Okt

# %%
# 필요하지만 단어 해석에 있어서는 중요도가 떨어지는 리스트
stop_words_list = stopwords.words('english')
print('불용어 개수 : ', len(stop_words_list))
print('불용어 10개 출력 : ', stop_words_list[:10])
# Out:
# 불용어 개수 :  198
# 불용어 10개 출력 :  ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
example = "Family is not an important thing. It's everything."
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example)

result = []
for word in word_tokens:
    if word not in stop_words:
        result.append(word)

print('불용어 제거 전 : ', word_tokens)
print('불용어 제거 후 : ', result)
# Out:
# 불용어 제거 전 :  ['Family', 'is', 'not', 'an', 'important', 'thing', '.', 'It', "'s", 'everything', '.']
# 불용어 제거 후 :  ['Family', 'important', 'thing', '.', 'It', "'s", 'everything', '.']
