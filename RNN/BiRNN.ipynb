# %%
import torch

# %%
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
inputs = torch.Tensor(1, 10, 5)

# %%
cell = nn.RNN(input_size= 5, hidden_size= 8, num_layers= 2, batch_first= True, bidirectional= True)
# BiRNN을 사용하기 위해서는 nn.RNN() 에 num_layers = 2로, bidirectional = True를 사용해야 함

# %%
outputs, _status = cell(inputs)

# %%
print(outputs.shape) # hidden size는 8 인데 16으로 출력이 된 이유는 
# bidirectional 이기 때문에 x 2 임
# Out:
# torch.Size([1, 10, 16])

# %%
print(_status.shape)
# Out:
# torch.Size([4, 1, 8])
